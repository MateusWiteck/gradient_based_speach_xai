# %% [markdown]
# # 07 - Deletion/Occlusion Evaluation
#
# Goal: measure confidence drop for the original predicted class after equal-duration silence masking.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

import pandas as pd

from speech_xai_project import config, evaluation

project_config = config.load_config(PROJECT_ROOT / 'configs' / 'default.yaml')
DELETION_RESULTS_CSV = config.project_path(project_config['paths']['deletion_results_csv'])
BUDGETS = project_config['evaluation']['budgets']
DELETION_RESULTS_CSV.parent.mkdir(parents=True, exist_ok=True)

# %%
# Evaluation loop sketch:
# for each audio:
#   original_prediction = classify original waveform
#   for method in conditions:
#       for budget in BUDGETS:
#           selected_intervals = ...
#           masked_waveform = masking.silence_intervals(...)
#           masked_prediction = classify masked waveform
#           result = evaluation.build_deletion_result(...)
# deletion_results_table.to_csv(DELETION_RESULTS_CSV, index=False)

print('Port the verified masking logic from Notebook 06 into this evaluation loop.')

# %% [markdown]
# ## Current status
#
# - Tested: confidence drop, relative drop, and prediction flip rate.
# - Works: fill in after running.
# - Failed: fill in after running.
# - Generated: `results/deletion_results.csv`.
# - Next: create qualitative examples in Notebook 08.
