# %% [markdown]
# # 06 - Unified Interval Representation and Masking
#
# Goal: select equal-duration intervals and silence them while preserving audio length.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

import pandas as pd

from speech_xai_project import audio, config, intervals, masking, plotting

project_config = config.load_config(PROJECT_ROOT / 'configs' / 'default.yaml')
BUDGETS = project_config['evaluation']['budgets']
LEGRAD_EXPLANATIONS_CSV = config.project_path(project_config['paths']['legrad_explanations_csv'])
SPEECHXAI_EXPLANATIONS_CSV = config.project_path(project_config['paths']['speechxai_explanations_csv'])

# %%
# Example once audio metadata and explanation CSVs exist:
# legrad_table = pd.read_csv(LEGRAD_EXPLANATIONS_CSV)
# speechxai_table = pd.read_csv(SPEECHXAI_EXPLANATIONS_CSV)
# selected = intervals.select_intervals_by_budget(legrad_table_for_audio, audio_duration, 0.2, mode='top')
# masked_waveform = masking.silence_intervals(waveform, sample_rate, selected)
# print(masking.total_interval_duration(selected))

print('Load explanation CSVs, choose one audio, and verify equal masked durations here.')

# %% [markdown]
# ## Current status
#
# - Tested: top, bottom, and random same-duration masking.
# - Works: fill in after running.
# - Failed: fill in after running.
# - Generated: optional masked waveform examples.
# - Next: run deletion evaluation in Notebook 07.
