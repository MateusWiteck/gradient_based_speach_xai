# %% [markdown]
# # 03 - Attention Gradient Test
#
# Goal: verify gradients with respect to attention maps for the predicted class score.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

import torch

from speech_xai_project import legrad

# Reuse the working attention-access path discovered in Notebook 02.
# Run forward with output_attentions=True, call legrad.retain_attention_gradients(attentions),
# select the predicted class logit, then backward().

# %%
# Template once logits and attentions are available:
# attentions = outputs.attentions
# legrad.retain_attention_gradients(attentions)
# predicted_index = int(torch.argmax(logits, dim=-1).item())
# class_score = logits[0, predicted_index]
# class_score.backward()
# for layer_index, attention in enumerate(attentions):
#     gradient = attention.grad
#     print(layer_index, attention.shape, None if gradient is None else gradient.shape)

print('Fill this notebook with the working forward pass from Notebook 02.')

# %% [markdown]
# ## Current status
#
# - Tested: attention-gradient capture with hooks or retained returned attentions.
# - Works: fill in after running.
# - Failed: fill in after running.
# - Generated: optional `results/gradient_debug.pkl`.
# - Next: implement LeGrad-inspired relevance in Notebook 04 only after gradients are nonzero.
