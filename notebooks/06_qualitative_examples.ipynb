# %% [markdown]
# # 06 - Qualitative Examples
#
# Goal: create report-ready examples showing waveform, SpeechXAI intervals, LeGrad relevance, masked regions, and confidence changes.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

import pandas as pd

from speech_xai_project import config, plotting

project_config = config.load_config(PROJECT_ROOT / 'configs' / 'default.yaml')
DELETION_RESULTS_CSV = config.project_path(project_config['paths']['deletion_results_csv'])

# %%
# Choose examples after deletion_results.csv exists:
# - methods agree
# - LeGrad larger drop
# - SpeechXAI larger drop
# - random competitive or both fail

print('Load deletion results and build representative figures here.')
# Out:
# Load deletion results and build representative figures here.

# %% [markdown]
# ## Current status
#
# - Tested: qualitative example selection and visualization.
# - Works: fill in after running.
# - Failed: fill in after running.
# - Generated: report-ready figures.
# - Next: use these selected figures together with Notebook 05's aggregate tables in the final report.
