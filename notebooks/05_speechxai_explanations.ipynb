# %% [markdown]
# # 05 - SpeechXAI Explanations
#
# Goal: run SpeechXAI and save segment-level explanations in the same interval format as LeGrad.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

import pandas as pd

from speech_xai_project import config, plotting

project_config = config.load_config(PROJECT_ROOT / 'configs' / 'default.yaml')
SPEECHXAI_EXPLANATIONS_CSV = config.project_path(project_config['paths']['speechxai_explanations_csv'])
SPEECHXAI_EXPLANATIONS_CSV.parent.mkdir(parents=True, exist_ok=True)

# %%
# Install/import SpeechXAI here, then convert its segment output to:
# audio_id, start, end, score
# speechxai_explanations_table.to_csv(SPEECHXAI_EXPLANATIONS_CSV, index=False)

print('Add SpeechXAI integration after confirming its local installation/API.')

# %% [markdown]
# ## Current status
#
# - Tested: SpeechXAI segment-level explanation extraction.
# - Works: fill in after running.
# - Failed: fill in after running.
# - Generated: `results/speechxai_explanations.csv`.
# - Next: unify intervals and implement silence masking in Notebook 06.
